# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os

from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 1

# %% [markdown]
# Tenemos 500000 imagenes RGB de 32x32, de 10 clases distintas (es decir 10 ouputs)
# Empezamos cambiando la arquitectura.
# Primero voy a añadir mayor cantidad de capas y neuronas. 4 capas de 64 neuronas y en medio un max pooling.

# %%
model = ks.Sequential()
#Extraccion de features
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))  

model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))

model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))
#Clasificacion 

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
#no cambiar esta linea de activacion
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       36992
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 256)         590080
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 256)         590080
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_9 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten_6 (Flatten)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 512)               2097664
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,468,746
# Trainable params: 4,468,746
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
##Montamos la red neuronal

# %%
print(model_tl.trainable)
# Out:
# True

# %% [markdown]
# # Montamos la capa de clasificación

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ##Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Callback con EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=5)

# Callback con EarlyStopping basada en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=45, 
                    use_multiprocessing=True, batch_size= 512, 
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/45
# 79/79 [==============================] - 19s 101ms/step - loss: 2.1082 - accuracy: 0.1848 - val_loss: 1.9337 - val_accuracy: 0.2582
# Epoch 2/45
# 79/79 [==============================] - 7s 91ms/step - loss: 1.6928 - accuracy: 0.3483 - val_loss: 1.4580 - val_accuracy: 0.4529
# Epoch 3/45
# 79/79 [==============================] - 7s 90ms/step - loss: 1.4126 - accuracy: 0.4734 - val_loss: 1.2793 - val_accuracy: 0.5226
# Epoch 4/45
# 79/79 [==============================] - 7s 91ms/step - loss: 1.2101 - accuracy: 0.5598 - val_loss: 1.1937 - val_accuracy: 0.5865
# Epoch 5/45
# 79/79 [==============================] - 7s 90ms/step - loss: 1.0574 - accuracy: 0.6211 - val_loss: 0.9660 - val_accuracy: 0.6569
# Epoch 6/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.9375 - accuracy: 0.6680 - val_loss: 0.9235 - val_accuracy: 0.6753
# Epoch 7/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.8537 - accuracy: 0.6985 - val_loss: 0.7773 - val_accuracy: 0.7245
# Epoch 8/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7705 - accuracy: 0.7306 - val_loss: 0.7259 - val_accuracy: 0.7458
# Epoch 9/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.7196 - accuracy: 0.7487 - val_loss: 0.7201 - val_accuracy: 0.7502
# Epoch 10/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.6762 - accuracy: 0.7655 - val_loss: 0.6837 - val_accuracy: 0.7598
# Epoch 11/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.6060 - accuracy: 0.7898 - val_loss: 0.6320 - val_accuracy: 0.7771
# Epoch 12/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.5786 - accuracy: 0.7996 - val_loss: 0.6034 - val_accuracy: 0.7888
# Epoch 13/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.5388 - accuracy: 0.8133 - val_loss: 0.5879 - val_accuracy: 0.7984
# Epoch 14/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.5009 - accuracy: 0.8269 - val_loss: 0.6478 - val_accuracy: 0.7811
# Epoch 15/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.4830 - accuracy: 0.8319 - val_loss: 0.6282 - val_accuracy: 0.7889
# Epoch 16/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.4581 - accuracy: 0.8410 - val_loss: 0.6007 - val_accuracy: 0.7943
# Epoch 17/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.4277 - accuracy: 0.8522 - val_loss: 0.5434 - val_accuracy: 0.8186
# Epoch 18/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.3975 - accuracy: 0.8622 - val_loss: 0.6032 - val_accuracy: 0.8042
# Epoch 19/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.3746 - accuracy: 0.8678 - val_loss: 0.5728 - val_accuracy: 0.8156
# Epoch 20/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.3817 - accuracy: 0.8682 - val_loss: 0.5954 - val_accuracy: 0.8093
# Epoch 21/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.3400 - accuracy: 0.8803 - val_loss: 0.5795 - val_accuracy: 0.8147
# Epoch 22/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.3394 - accuracy: 0.8820 - val_loss: 0.5474 - val_accuracy: 0.8287
# Epoch 23/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.3143 - accuracy: 0.8911 - val_loss: 0.5827 - val_accuracy: 0.8215
# Epoch 24/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2915 - accuracy: 0.8986 - val_loss: 0.6435 - val_accuracy: 0.8142
# Epoch 25/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2951 - accuracy: 0.8987 - val_loss: 0.5430 - val_accuracy: 0.8348
# Epoch 26/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2751 - accuracy: 0.9050 - val_loss: 0.5852 - val_accuracy: 0.8262
# Epoch 27/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.2785 - accuracy: 0.9033 - val_loss: 0.5729 - val_accuracy: 0.8277
# Epoch 28/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2691 - accuracy: 0.9064 - val_loss: 0.5610 - val_accuracy: 0.8340
# Epoch 29/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2543 - accuracy: 0.9135 - val_loss: 0.5631 - val_accuracy: 0.8326
# Epoch 30/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.2270 - accuracy: 0.9218 - val_loss: 0.5740 - val_accuracy: 0.8351
# Epoch 31/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2275 - accuracy: 0.9187 - val_loss: 0.5744 - val_accuracy: 0.8301
# Epoch 32/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2090 - accuracy: 0.9282 - val_loss: 0.6544 - val_accuracy: 0.8264
# Epoch 33/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2113 - accuracy: 0.9274 - val_loss: 0.5812 - val_accuracy: 0.8361
# Epoch 34/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.2207 - accuracy: 0.9238 - val_loss: 0.5635 - val_accuracy: 0.8408
# Epoch 35/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.2025 - accuracy: 0.9299 - val_loss: 0.5862 - val_accuracy: 0.8380
# Epoch 36/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1817 - accuracy: 0.9359 - val_loss: 0.6291 - val_accuracy: 0.8348
# Epoch 37/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1929 - accuracy: 0.9339 - val_loss: 0.6657 - val_accuracy: 0.8271
# Epoch 38/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.1900 - accuracy: 0.9360 - val_loss: 0.6218 - val_accuracy: 0.8368
# Epoch 39/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.1730 - accuracy: 0.9402 - val_loss: 0.6215 - val_accuracy: 0.8407
# Epoch 40/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1782 - accuracy: 0.9385 - val_loss: 0.6561 - val_accuracy: 0.8285
# Epoch 41/45
# 79/79 [==============================] - 7s 92ms/step - loss: 0.1696 - accuracy: 0.9413 - val_loss: 0.6674 - val_accuracy: 0.8295
# Epoch 42/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1701 - accuracy: 0.9410 - val_loss: 0.6227 - val_accuracy: 0.8339
# Epoch 43/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1746 - accuracy: 0.9387 - val_loss: 0.6516 - val_accuracy: 0.8312
# Epoch 44/45
# 79/79 [==============================] - 7s 90ms/step - loss: 0.1577 - accuracy: 0.9458 - val_loss: 0.6214 - val_accuracy: 0.8424
# Epoch 45/45
# 79/79 [==============================] - 7s 91ms/step - loss: 0.1435 - accuracy: 0.9505 - val_loss: 0.6062 - val_accuracy: 0.8437

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:06:23.823696

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 84.080

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
