# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Conectemonos a Google Drive y preparemos los datos
#
# Los datos los podeis encontrar en esta URL de Google Drive (formato NPZ)
#
# https://drive.google.com/file/d/1-OplAg9THXuzKC_oYAiB4wdBmCTdiy4z/view?usp=sharing <br>
# https://drive.google.com/file/d/1-Svi93L-C7qAq2oJmtajfCJDjGdJTIaE/view?usp=sharing <br>
# https://drive.google.com/file/d/1-Dpozh1KCEvuCYgYuaf98-PzHhHTo3F_/view?usp=sharing <br>
#
# Movedlos a vuestro Drive!!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import os

from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 3. Definimos algunas constantes

# %%
ANCHO_IMAGEN=150
ALTURA_IMAGEN=150
IMAGE_SIZE=(ANCHO_IMAGEN, ALTURA_IMAGEN)
CANALES_IMAGENES=3

# Definimos la ruta donde teneis los archivos NPZ dentro de Google Drive
ruta = "/content/drive/MyDrive/00_Nuclio_DS_Master/Dogs-vs-cats/"

# %% [markdown]
# ## 4. Preparamos los datos de entrenamiento
#
# Los cargaremos del formato NPZ que comentamos en la última clase, y que tenemos en el Drive

# %%
dict_npz = np.load(ruta+'xy_train_img.npz')
x_train_img = dict_npz['x']
y_train_img = dict_npz['y']

dict_npz = np.load(ruta+'xy_test_img.npz')
x_test_img = dict_npz['x']
y_test_img = dict_npz['y']

dict_npz = np.load(ruta+'xy_val_img.npz')
x_val_img = dict_npz['x']
y_val_img = dict_npz['y']

x_train_scaled = x_train_img / 255.
x_test_scaled = x_test_img / 255.
x_val_scaled = x_val_img / 255.

# %%
print("Tamaño X train:", x_train_scaled.shape)
print("Tamaño Y train:", y_train_img.shape)

print("Tamaño X test:", x_test_scaled.shape)
print("Tamaño Y test:", y_test_img.shape)

print("Tamaño X val:", x_val_scaled.shape)
print("Tamaño Y val:", y_val_img.shape)
# Out:
# Tamaño X train: (5000, 150, 150, 3)
# Tamaño Y train: (5000,)
# Tamaño X test: (1000, 150, 150, 3)
# Tamaño Y test: (1000,)
# Tamaño X val: (1000, 150, 150, 3)
# Tamaño Y val: (1000,)

# %% [markdown]
# ## 5. Exploremos los datos

# %%
df_train = pd.DataFrame(y_train_img, columns=['category'])
df_train['category'].value_counts().plot.bar()

# %% [markdown]
# Como podemos ver tenemos 2500 ejemplos de cada clase... poquito para ser una red neuronal para vision por computador... ya vereis...

# %% [markdown]
# ## 6. Pintemos una imagen

# %%
sample = random.choice(range(0,4999))
image = x_train_scaled[sample]
plt.imshow(image, cmap=plt.cm.binary)

# %% [markdown]
# ## 7. Apilemos bloques para hacer el modelo
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(16, (3, 3), activation='relu', 
                           input_shape=(ANCHO_IMAGEN, ALTURA_IMAGEN, CANALES_IMAGENES)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(1, activation='sigmoid')) # 1 de salida porque tenemos dos valores posibles 0 o 1 (tras aplicar un label encoder a dog y cat)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        9280
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3,706,113
# Trainable params: 3,706,113
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 8. Montemos el optimizador compilando el modelo

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# ## 9. Definamos un callback para el Early Stopping

# %% [markdown]
# **Early Stopping**
#
# Prevenimos el sobre ajuste parando cuando tras 10 epochs y el error de la validacion no decrementa (estamos en una plateau)

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=5)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 10. Preparamos los datos

# %% [markdown]
# Haremos un one-hot encoding que nos va a ir bien para nuestra clasificación, porque lo que viene de serie son cadena de texto 'dog' y 'cat'

# %%
y_train_img
# Out:
# array(['cat', 'cat', 'cat', ..., 'dog', 'dog', 'dog'], dtype='<U3')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train_img)
y_train_encoded = le.transform(y_train_img)
y_val_encoded = le.transform(y_val_img)
y_test_encoded = le.transform(y_test_img)

# %%
y_train_encoded
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# ## 11. Transformador de imagenes a datos consumibles por la red neuronal
#
# **De entrenamiento**
#
# Aquí incluiremos nuestra parte de generación de imagenes (con código de partida)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255, 
    brightness_range = (0.6, 1.1),
    rotation_range = 30,
    zoom_range = 0.3,
    horizontal_flip = True

    
    # Definamos las transformaciones

    )

train_generator = train_datagen.flow(
    x_train_img,  # Aquí hay que usar datos NO re-escalados... de ahi que no usemos x_train_rescaled!
    y_train_encoded, 
    batch_size=30
)

# %% [markdown]
# **De validacion (test no lo necesita)**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val_img, 
    y_val_encoded, 
    batch_size=20
)

# %% [markdown]
# No tiene mala pinta!!

# %% [markdown]
# ## 12. Veamos que pinta tiene el generador de datos
#
# A rellenar para ver que nos da el generador de imagenes nuevas

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train_img[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
    )

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. Entrenemos el modelo!

# %%
epochs = 200

# Este FIT hay que cambiarlo!!

#history = model.fit(x_train_scaled, y_train_encoded, epochs=epochs, 
#                    validation_data=(x_val_scaled, y_val_encoded), batch_size=512, 
#                    callbacks=[callback_val_loss, callback_val_accuracy])

history = model.fit(train_generator, epochs = epochs,
                    validation_data = validation_generator,
                    steps_per_epoch = 167, # Los steps en funcion de la cantidad de imagenes y el batch size del train generator (5000/30 = 166.66667)
                    validation_steps = 50, # Numero imagenes validacion / batch del validation generator = 1000 / 20 = 50
                    callbacks=[callback_val_loss, callback_val_accuracy]
                    )
# Out:
# Epoch 1/200
# 167/167 [==============================] - 39s 215ms/step - loss: 0.6773 - accuracy: 0.5576 - val_loss: 0.6680 - val_accuracy: 0.6080
# Epoch 2/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.6508 - accuracy: 0.6148 - val_loss: 0.6412 - val_accuracy: 0.6250
# Epoch 3/200
# 167/167 [==============================] - 37s 221ms/step - loss: 0.6192 - accuracy: 0.6488 - val_loss: 0.5977 - val_accuracy: 0.6660
# Epoch 4/200
# 167/167 [==============================] - 36s 217ms/step - loss: 0.6234 - accuracy: 0.6544 - val_loss: 0.5924 - val_accuracy: 0.7030
# Epoch 5/200
# 167/167 [==============================] - 37s 220ms/step - loss: 0.5850 - accuracy: 0.6968 - val_loss: 0.5764 - val_accuracy: 0.6980
# Epoch 6/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.5599 - accuracy: 0.7158 - val_loss: 0.4958 - val_accuracy: 0.7570
# Epoch 7/200
# 167/167 [==============================] - 35s 211ms/step - loss: 0.5370 - accuracy: 0.7276 - val_loss: 0.5179 - val_accuracy: 0.7460
# Epoch 8/200
# 167/167 [==============================] - 35s 209ms/step - loss: 0.5363 - accuracy: 0.7182 - val_loss: 0.4766 - val_accuracy: 0.7830
# Epoch 9/200
# 167/167 [==============================] - 36s 212ms/step - loss: 0.5097 - accuracy: 0.7502 - val_loss: 0.5112 - val_accuracy: 0.7650
# Epoch 10/200
# 167/167 [==============================] - 35s 212ms/step - loss: 0.5107 - accuracy: 0.7498 - val_loss: 0.4551 - val_accuracy: 0.8010
# Epoch 11/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.5034 - accuracy: 0.7592 - val_loss: 0.4421 - val_accuracy: 0.8210
# Epoch 12/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.4835 - accuracy: 0.7694 - val_loss: 0.4936 - val_accuracy: 0.7670
# Epoch 13/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.4759 - accuracy: 0.7714 - val_loss: 0.4641 - val_accuracy: 0.7950
# Epoch 14/200
# 167/167 [==============================] - 35s 211ms/step - loss: 0.4477 - accuracy: 0.7922 - val_loss: 0.4888 - val_accuracy: 0.7820
# Epoch 15/200
# 167/167 [==============================] - 36s 217ms/step - loss: 0.4390 - accuracy: 0.7964 - val_loss: 0.4209 - val_accuracy: 0.8080
# Epoch 16/200
# 167/167 [==============================] - 35s 212ms/step - loss: 0.4267 - accuracy: 0.8076 - val_loss: 0.4074 - val_accuracy: 0.8130
# Epoch 17/200
# 167/167 [==============================] - 36s 218ms/step - loss: 0.4109 - accuracy: 0.8096 - val_loss: 0.3938 - val_accuracy: 0.8250
# Epoch 18/200
# 167/167 [==============================] - 37s 220ms/step - loss: 0.4155 - accuracy: 0.8090 - val_loss: 0.3956 - val_accuracy: 0.8360
# Epoch 19/200
# 167/167 [==============================] - 35s 211ms/step - loss: 0.3961 - accuracy: 0.8230 - val_loss: 0.4064 - val_accuracy: 0.8280
# Epoch 20/200
# 167/167 [==============================] - 35s 210ms/step - loss: 0.3874 - accuracy: 0.8314 - val_loss: 0.3578 - val_accuracy: 0.8420
# Epoch 21/200
# 167/167 [==============================] - 35s 208ms/step - loss: 0.3826 - accuracy: 0.8250 - val_loss: 0.3760 - val_accuracy: 0.8460
# Epoch 22/200
# 167/167 [==============================] - 36s 216ms/step - loss: 0.3855 - accuracy: 0.8296 - val_loss: 0.3902 - val_accuracy: 0.8310
# Epoch 23/200
# 167/167 [==============================] - 35s 209ms/step - loss: 0.3552 - accuracy: 0.8444 - val_loss: 0.3347 - val_accuracy: 0.8540
# Epoch 24/200
# 167/167 [==============================] - 34s 205ms/step - loss: 0.3608 - accuracy: 0.8492 - val_loss: 0.3786 - val_accuracy: 0.8500
# Epoch 25/200
# 167/167 [==============================] - 35s 208ms/step - loss: 0.3531 - accuracy: 0.8474 - val_loss: 0.3640 - val_accuracy: 0.8490
# Epoch 26/200
# 167/167 [==============================] - 35s 209ms/step - loss: 0.3377 - accuracy: 0.8602 - val_loss: 0.3491 - val_accuracy: 0.8400
# Epoch 27/200
# 167/167 [==============================] - 35s 210ms/step - loss: 0.3230 - accuracy: 0.8574 - val_loss: 0.3367 - val_accuracy: 0.8570
# Epoch 28/200
# 167/167 [==============================] - 35s 212ms/step - loss: 0.3106 - accuracy: 0.8654 - val_loss: 0.2964 - val_accuracy: 0.8860
# Epoch 29/200
# 167/167 [==============================] - 35s 208ms/step - loss: 0.3207 - accuracy: 0.8624 - val_loss: 0.3005 - val_accuracy: 0.8750
# Epoch 30/200
# 167/167 [==============================] - 36s 213ms/step - loss: 0.3003 - accuracy: 0.8692 - val_loss: 0.3214 - val_accuracy: 0.8710
# Epoch 31/200
# 167/167 [==============================] - 35s 210ms/step - loss: 0.3019 - accuracy: 0.8688 - val_loss: 0.3180 - val_accuracy: 0.8600
# Epoch 32/200
# 167/167 [==============================] - 35s 209ms/step - loss: 0.2989 - accuracy: 0.8712 - val_loss: 0.3239 - val_accuracy: 0.8530
# Epoch 33/200
# 167/167 [==============================] - 34s 206ms/step - loss: 0.2888 - accuracy: 0.8772 - val_loss: 0.3971 - val_accuracy: 0.8510

# %% [markdown]
# ## 14. Guardemos el modelo

# %%
model.save(ruta+"model_con_data_augmentation.h5")

# %% [markdown]
# ## 15. Veamos los resultados

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='validation')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='validation')
plt.legend()
plt.show()

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Test del Modelo con Data Augmentation > %.3f' % (acc * 100.0))
# Out:
# Test del Modelo con Data Augmentation > 85.900

# %% [markdown]
# ## 16. Pintemos algunas predicciones

# %%
predictions = model.predict(x_test_scaled)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  if true_label == 1:
    true_label = 'dog'
  else:
    true_label = 'cat'

  if np.max(predictions_array) > 0.50:
    predicted_label = 'dog'
  else:
    predicted_label = 'cat'

  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(1))
  plt.yticks([])

  if true_label == 1:
    true_label = 'dog'
  else:
    true_label = 'cat'

  if np.max(predictions_array) > 0.50:
    predicted_label = 'dog'
  else:
    predicted_label = 'cat'

  if predicted_label == true_label:
    color_plt = 'blue'
  else:
    color_plt = 'red'

  thisplot = plt.bar(range(1), np.max(predictions_array), color=color_plt)
  plt.ylim([0, 1])

# %% [markdown]
# Dibujamos los primeros digitos, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo

# %%
num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test_encoded, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test_encoded)
plt.tight_layout()
plt.show()
