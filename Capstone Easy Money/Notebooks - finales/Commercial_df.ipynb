# %%
import numpy as np 
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.style.use('ggplot')
pd.set_option('display.max_rows', 500)
pd.options.display.float_format = '{:,.2f}'.format

# %%
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ca_file = '/content/drive/MyDrive/Nuclio/Capstone/commercial_activity_df.csv'

# %%
commercial = pd.read_csv(ca_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-419b60272225> in <module>()
# ----> 1 commercial = pd.read_csv(ca_file)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
commercial.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6d136e20f88b> in <module>()
# ----> 1 commercial.head()
#
# NameError: name 'commercial' is not defined

# %%
commercial.info(verbose=True)

# %%
commercial.isnull().sum()

# %%
commercial ["entry_channel"].value_counts(dropna = False)

# %%
commercial ["entry_channel"].mode()

# %%
#commercial['entry_channel'].fillna(commercial['entry_channel'].mode(), inplace=True)

# %%
commercial['entry_channel'].fillna("KHE", inplace = True)

# %%
commercial["segment"].value_counts(dropna = False)

# %%
commercial['segment'].mode()

# %%
commercial['segment'].fillna("03 - UNIVERSITARIO", inplace=True)

# %%
#commercial['segment'].fillna(commercial['segment'].mode(),inplace=True)

# %%
commercial.isna().sum()

# %%
commercial ["entry_date"] = pd.to_datetime(commercial["pk_partition"], format = "%Y-%m-%d")

# %%
commercial ["pk_partition"] = pd.to_datetime(commercial["pk_partition"], format = "%Y-%m-%d")

# %%
commercial.info()

# %%
#hasta acá sigue para visualizaciones
#habría que armar df transformando variables para kmeans
